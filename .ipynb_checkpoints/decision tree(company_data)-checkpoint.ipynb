# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv('Company_Data.csv')

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
sales=pd.cut(df.Sales,bins=[0,8,16],labels=['Normal','High'])
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
sales
# Out:
# 0        High
# 1        High
# 2        High
# 3      Normal
# 4      Normal
#         ...
# 395      High
# 396    Normal
# 397    Normal
# 398    Normal
# 399      High
# Name: Sales, Length: 400, dtype: category
# Categories (2, object): ['Normal' < 'High']

# %%
target=pd.DataFrame(sales)
target
# Out:
#       Sales
# 0      High
# 1      High
# 2      High
# 3    Normal
# 4    Normal
# ..      ...
# 395    High
# 396  Normal
# 397  Normal
# 398  Normal
# 399    High
#
# [400 rows x 1 columns]

# %%
target.shape
# Out:
# (400, 1)

# %%
features=df.drop('Sales',axis=1)
features
# Out:
#      CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0          138      73           11         276    120       Bad   42
# 1          111      48           16         260     83      Good   65
# 2          113      35           10         269     80    Medium   59
# 3          117     100            4         466     97    Medium   55
# 4          141      64            3         340    128       Bad   38
# ..         ...     ...          ...         ...    ...       ...  ...
# 395        138     108           17         203    128      Good   33
# 396        139      23            3          37    120    Medium   55
# 397        162      26           12         368    159    Medium   40
# 398        100      79            7         284     95       Bad   50
# 399        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# ...

# %%
features=pd.get_dummies(features)
features
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0          138      73           11         276    120   42         17
# 1          111      48           16         260     83   65         10
# 2          113      35           10         269     80   59         12
# 3          117     100            4         466     97   55         14
# 4          141      64            3         340    128   38         13
# ..         ...     ...          ...         ...    ...  ...        ...
# 395        138     108           17         203    128   33         14
# 396        139      23            3          37    120   55         11
# 397        162      26           12         368    159   40         18
# 398        100      79            7         284     95   50         12
# 399        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# ...

# %%
target.isnull().sum()
# Out:
# Sales    2
# dtype: int64

# %%
features.isnull().sum()
# Out:
# CompPrice           0
# Income              0
# Advertising         0
# Population          0
# Price               0
# Age                 0
# Education           0
# ShelveLoc_Bad       0
# ShelveLoc_Good      0
# ShelveLoc_Medium    0
# Urban_No            0
# Urban_Yes           0
# US_No               0
# US_Yes              0
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(features,target,train_size=0.75,random_state=100)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (300, 14)
# (100, 14)
# (300, 1)
# (100, 1)

# %%
x_train
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 163        130      64            0          40    106   39         17
# 229         98     104            0         404     72   27         18
# 213        149      84            5         220    139   33         10
# 188        116      37            0         426     90   76         15
# 386        152     116            0         170    160   39         16
# ..         ...     ...          ...         ...    ...  ...        ...
# 343        117      42           10         371    121   26         14
# 359        130      62           11         396    130   66         14
# 323        107     105           18         428    103   34         12
# 280        121      86           10         496    145   51         10
# 8          132     110            0         108    124   76         10
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# ...

# %%
x_train.isnull().sum()
# Out:
# CompPrice           0
# Income              0
# Advertising         0
# Population          0
# Price               0
# Age                 0
# Education           0
# ShelveLoc_Bad       0
# ShelveLoc_Good      0
# ShelveLoc_Medium    0
# Urban_No            0
# Urban_Yes           0
# US_No               0
# US_Yes              0
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# Sales    1
# dtype: int64

# %%
simple_impute=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
y_train= simple_impute.fit_transform(y_train)

# %%
dec_tree=DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=3)

# %%
dec_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred=dec_tree.predict(x_test)

# %%
y_pred
# Out:
# array(['Normal', 'High', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'High', 'High', 'High', 'High', 'High', 'Normal', 'High',
#        'High', 'High', 'Normal', 'High', 'Normal', 'High', 'Normal',
#        'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal', 'High',
#        'Normal', 'High', 'Normal', 'High', 'Normal', 'High', 'Normal',
#        'High', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'High',
#        'High', 'High', 'Normal', 'High', 'Normal', 'High', 'Normal',
#        'High', 'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal',
#        'High', 'Normal', 'High', 'High', 'Normal', 'High', 'Normal',
#        'High', 'Normal', 'Normal', 'Normal', 'High', 'High', 'Normal',
#        'Normal', 'High', 'High', 'High', 'High', 'Normal', 'Normal',
#        'Normal', 'Normal', 'High', 'High', 'High', 'Normal', 'High',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'High',
# ...

# %%
y_test
# Out:
#       Sales
# 248  Normal
# 318    High
# 173  Normal
# 285  Normal
# 184    High
# ..      ...
# 380    High
# 311  Normal
# 110    High
# 90   Normal
# 6    Normal
#
# [100 rows x 1 columns]

# %%
plt.figure(figsize=(15,8))
plot_tree(dec_tree,filled=True,rounded=True,feature_names=feature_names)
plt.show()

# %%
features.columns
# Out:
# Index(['CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'Age',
#        'Education', 'ShelveLoc_Bad', 'ShelveLoc_Good', 'ShelveLoc_Medium',
#        'Urban_No', 'Urban_Yes', 'US_No', 'US_Yes'],
#       dtype='object')

# %%
feature_names=['CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'Age',
       'Education', 'ShelveLoc_Bad', 'ShelveLoc_Good', 'ShelveLoc_Medium',
       'Urban_No', 'Urban_Yes', 'US_No', 'US_Yes']
